# %%
#O programa pede um número:
num = int(input("Digite um numero: "))

#Se o resto da divisão por 2 for igual a zero, então o número será par. Senão, ímpar    
if num % 2 == 0 :
        print("O numero ", num, "é par!")
else:
        print("O numero ", num, "é impar!")
# Out:
# Digite um numero: 5
# O numero  5 é impar!

# %%
#O programa pede um número:
num = int(input("Digite um numero: "))
#resto = num % 2 

#Se o número for múltiplo de 4, uma mensagem diferenciada será exibida. 
#se não, se o resto da divisão por 2 for igual a zero, então o número será par. Senão, ímpar    

if num % 4 == 0 :
    print("Olha lá!! Um par diferenciado!!")
    
elif num % 2 == 0 :
        print("O numero ", num, "é par!")
else:
        print("O numero ", num, "é impar!")

# %%
#O programa pede um número:
num = int(input("Digite um numero: "))
#resto = num % 2 

#Se o número for múltiplo de 4, uma mensagem diferenciada será exibida. 
#se não, se o resto da divisão por 2 for igual a zero, então o número será par. Senão, ímpar    

if num % 4 == 0 :
    print("Olha lá!! Um par diferenciado!!")
    
elif num % 2 == 0 :
        print("O numero ", num, "é par!")
else:
        print("O numero ", num, "é impar!")

        #O Programa continua e pede dois números. Depois checa se a divião entre eles é par ou não.
num1 = float(input("Digite um número: "))
num2 = float(input("Digite um número para ser o divisor: "))

evenly = num1 % num2 

if evenly == 0:
    
    print("a divisao é par")
    
else :
    print("a divisão é ímpar")
# Out:
# Digite um numero: 80
# Olha lá!! Um par diferenciado!!
# Digite um número: 5789
# Digite um número para ser o divisor: 32
# a divisão é ímpar

# %%
a = int(input("Olá, digite uma quantidade de objetos a serem distribuidos: \n \n Para encerrar digite '0' "))
       
eu = []
x = []

while a != 0:
  
    if a % 2 == 0:
        eu.append(a)
        a = a-1
    else:
        x.append(a)
        a = a - 1
        
        
        
print('Para mim: ',eu)
print('Para x: ', x)
# Out:
# Olá, digite uma quantidade de objetos a serem distribuidos:
#
#  Para encerrar digite '0' 50
# Para mim:  [50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# Para x:  [49, 47, 45, 43, 41, 39, 37, 35, 33, 31, 29, 27, 25, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]

# %%
a = [1, 4, 9, 11, 16, 25, 36, 49, 64, 81, 100]
primo = []
numero = 0
for numero in a:
    b = numero
    print(b)
    c = b - 1 
    print(a)
    
    if b != 1:
        
            
        while b != 0: 
            if c > 1 and b % c == 0:
                print(f'o número {b} não é primo')
                break
            elif c > 1 and b % c != 0:
                c = b - 1
                print('ola')
            else: 
                print(f'o número {b} é primo')
                primo.append(b)
             
            
    else:
         pass
             
    
print(primo)
# Out:
# 1
# [1, 4, 9, 11, 16, 25, 36, 49, 64, 81, 100]
# 4
# [1, 4, 9, 11, 16, 25, 36, 49, 64, 81, 100]
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ola
# ...
